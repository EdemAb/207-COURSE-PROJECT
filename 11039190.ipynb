# %% [markdown]
# |Course|:|SENG 207 - Programming for Engineers|
# |----|----|---|
# |Name|:|Edem Ablorde|
# |Index Number|:|11039190|
# |Class|:|MTEN|

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('red_wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
dataset.isna().any()
# Out:
# fixed acidity            True
# volatile acidity         True
# citric acid             False
# residual sugar          False
# chlorides                True
# free sulfur dioxide      True
# total sulfur dioxide    False
# density                  True
# pH                      False
# sulphates               False
# alcohol                 False
# quality                  True
# dtype: bool

# %%
#obtaining mean values to replace Na values 

mean_fixed_acidity = dataset['fixed acidity'].mean()
mean_volatile_acidity = dataset['volatile acidity'].mean()
mean_chlorides = dataset['chlorides'].mean()
mean_free_sulfur_dioxide = dataset['free sulfur dioxide'].mean()
mean_density = dataset['density'].mean()
mean_quality = dataset['quality'].mean()

# %%
mean_fixed_acidity = mean_fixed_acidity.round(2)
mean_volatile_acidity = mean_volatile_acidity.round(2)
mean_chlorides = mean_chlorides.round(3)
mean_free_sulfur_dioxide = mean_free_sulfur_dioxide.round(1)
mean_density = mean_density.round(4)
mean_quality = mean_quality.round(1)

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(mean_fixed_acidity)
dataset['volatile acidity'] = dataset['volatile acidity'].fillna(mean_volatile_acidity)
dataset['chlorides'] = dataset['chlorides'].fillna(mean_chlorides)
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(mean_free_sulfur_dioxide)
dataset['density'] = dataset['density'].fillna(mean_density)
dataset['quality'] = dataset['quality'].fillna(mean_quality)

# %%
mode_fixed_acidity = dataset['fixed acidity'].mode()
mode_residual_sugar = dataset['residual sugar'].mode()
mode_volatile_acidity = dataset['volatile acidity'].mode()
mode_citric_acid = dataset['citric acid'].mode()
mode_chlorides = dataset['chlorides'].mode()
mode_free_sulfur_dioxide = dataset['free sulfur dioxide'].mode()
mode_total_sulfur_dioxide = dataset['total sulfur dioxide'].mode()
mode_pH = dataset['pH'].mode()
mode_alcohol = dataset['alcohol'].mode()
mode_sulphates = dataset['sulphates'].mode()
mode_density = dataset['density'].mode()
mode_quality = dataset['quality'].mode()

# %%
print(f'fixed acidity mode: {mode_fixed_acidity}') 
print(f'volatile acidity mode: {mode_volatile_acidity }')
print(f'citric acid mode: {mode_citric_acid }')
print(f'residual sugar mode: {mode_residual_sugar}')
print(f'alcohol mode: {mode_alcohol}')
print(f'chlorides mode: {mode_chlorides}') 
print(f'free sulfur dioxide mode: {mode_free_sulfur_dioxide}')
print(f'free total dioxide mode: {mode_total_sulfur_dioxide}')
print(f'pH mode: {mode_pH}')
print(f'sulphates mode: {mode_sulphates}')
print(f'density mode: {mode_density}')
print(f'quality mode: {mode_quality}')
# Out:
# fixed acidity mode: 0    7.2
# Name: fixed acidity, dtype: float64
# volatile acidity mode: 0    0.6
# Name: volatile acidity, dtype: float64
# citric acid mode: 0    0.0
# Name: citric acid, dtype: float64
# residual sugar mode: 0    2.0
# Name: residual sugar, dtype: float64
# alcohol mode: 0    9.5
# Name: alcohol, dtype: float64
# chlorides mode: 0    0.08
# Name: chlorides, dtype: float64
# free sulfur dioxide mode: 0    6.0
# Name: free sulfur dioxide, dtype: float64
# free total dioxide mode: 0    28.0
# Name: total sulfur dioxide, dtype: float64
# pH mode: 0    3.3
# Name: pH, dtype: float64
# sulphates mode: 0    0.6
# Name: sulphates, dtype: float64
# density mode: 0    0.9972
# Name: density, dtype: float64
# quality mode: 0    5.0
# Name: quality, dtype: float64

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.318336          0.527749     0.270976        2.538806
# std         1.740318          0.179036     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087475            15.867355             46.467792     0.996745
# std       0.047058            10.455756             32.895324     0.001887
# ...

# %%
#verifying filling of na values
dataset.isna().any()
dataset.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.087
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataInfo = dataset.describe()
dataInfo = dataInfo[1:]
dataInfo
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# mean       8.318336          0.527749     0.270976        2.538806   0.087475
# std        1.740318          0.179036     0.194801        1.409928   0.047058
# min        4.600000          0.120000     0.000000        0.900000   0.012000
# 25%        7.100000          0.390000     0.090000        1.900000   0.070000
# 50%        7.900000          0.520000     0.260000        2.200000   0.079000
# 75%        9.200000          0.640000     0.420000        2.600000   0.090000
# max       15.900000          1.580000     1.000000       15.500000   0.611000
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# mean            15.867355             46.467792  0.996745  3.311113
# std             10.455756             32.895324  0.001887  0.154386
# min              1.000000              6.000000  0.990070  2.740000
# 25%              7.000000             22.000000  0.995600  3.210000
# ...

# %%
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255125     0.670971
# volatile acidity          -0.255125          1.000000    -0.552011
# citric acid                0.670971         -0.552011     1.000000
# residual sugar             0.114743          0.002072     0.143577
# chlorides                  0.093750          0.061059     0.203770
# free sulfur dioxide       -0.153683         -0.010499    -0.061855
# total sulfur dioxide      -0.112608          0.076853     0.035533
# density                    0.667523          0.021785     0.365352
# pH                        -0.682988          0.234789    -0.541904
# sulphates                  0.183212         -0.260860     0.312770
# alcohol                   -0.061048         -0.202080     0.109903
# quality                    0.124600         -0.390283     0.226054
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(19, 19))
plt.suptitle('HISTOGRAM OF VARIOUS DATA COLUMNS', fontsize=25)
for i in range(dataset.shape[1]):
    plt.subplot(6, 3, i + 1)
    sub_graph = plt.gca()
    sub_graph.set_title(dataset.columns.values[i])

    vals = np.size(dataset.iloc[:, i].unique())
    
    plt.hist(dataset.iloc[:, i], bins=vals, color='green')

# %%
FIG, axes = plt.subplots(3, 3, figsize=[15,12])
plt.subplots_adjust(wspace=0.2 , hspace=1)
dataInfo.loc['mean'].plot(ylabel='mean distribution', rot=45, ax=axes[0, 0], color='orange').set_title('MEAN')
dataInfo.loc['std'].plot(ylabel='standard deviation', rot=45, ax=axes[0, 1]).set_title('STANDARD DEVIATION')
dataInfo.loc['min'].plot(ylabel='minimum distribution', rot=45, ax=axes[0, 2], color='yellow').set_title('MINIMUM')
dataInfo.loc['25%'].plot(ylabel="25%_distribution", rot=45, ax=axes[1, 0], color='pink').set_title('LOWER QUARTILE')
dataInfo.loc['50%'].plot(ylabel='50%_distribution', rot=45, ax=axes[1, 1], color='gray').set_title('MEDIAN')
dataInfo.loc['75%'].plot(ylabel='75%_distribuiton', rot=45, ax=axes[1, 2], color='skyblue').set_title('UPPER QUARTILE')
dataInfo.loc['max'].plot(ylabel='maximum distribution', rot=45, ax=axes[2, 1], color='red').set_title('MAXIMUM')
# Out:
# Text(0.5, 1.0, 'MAXIMUM')

# %%
plt.hist(dataset['alcohol'], bins=20, edgecolor='black')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.title('ALCOHOL CONTENT DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'ALCOHOL CONTENT DISTRIBUTION')

# %%
dataset.corrwith(dataset.quality).plot.bar(title = "QUALITY CORRELATION", edgecolor='black', grid=True)
# Out:
# <Axes: title={'center': 'QUALITY CORRELATION'}>
